# %%
import urllib.request
from bs4 import BeautifulSoup
from pandas import DataFrame

url = 'https://movie.naver.com/movie/running/current.nhn' #원하는 검색 결과 url
html = urllib.request.urlopen(url).read() #url의 html을 가져온다. 이를 BeautifulSoup으로 분석한다.
soup = BeautifulSoup(html, 'html.parser') #분석할 기본 준비 완료

title = soup.select('#content > div.article > div:nth-child(1) > div.lst_wrap > ul > li > dl > dt > a')
for i in range(100):
    title[i] = title[i].text

genre = soup.select('#content > div.article > div:nth-child(1) > div.lst_wrap > ul > li > dl > dd:nth-child(3) > dl > dd:nth-child(2) > span.link_txt')
for i in range(100):
    genre[i] = genre[i].text.replace("\n","").replace("\r","").replace("\t","")

director = soup.select('#content > div.article > div:nth-child(1) > div.lst_wrap > ul > li > dl > dd:nth-child(3) > dl > dd:nth-child(4) > span')
for i in range(100):
    director[i] = director[i].text.replace("\n","").replace("\r","").replace("\t","")
    
actor = soup.select('#content > div.article > div:nth-child(1) > div.lst_wrap > ul > li > dl > dd:nth-child(3) > dl > dd:nth-child(6)')
for i in range(100):
    actor[i] = actor[i].text.replace("\n","").replace("\r","").replace("\t","")

rating = soup.select('#content > div.article > div:nth-child(1) > div.lst_wrap > ul > li > dl > dd.star > dl.info_star > dd > div > a > span.num')
for i in range(100):
    rating[i] = rating[i].text
    
Movie_List = []
for i in range(100):
    Movie_List.append(title[i])

Genre_List = []
for i in range(100):
    Genre_List.append(genre[i])

director_List = []
for i in range(100):
    director_List.append(director[i])

actor_List = []
for i in range(100):
    actor_List.append(actor[i])
    
rating_List = []
for i in range(100):
    rating_List.append(rating[i])
    
Movie ={'Title':Movie_List, 'Genre':Genre_List, 'Director':director_List, 'Actor':actor_List, 'Rating':rating_List}
Moviedf = DataFrame(Movie, columns = ['Title', 'Genre', 'Director', 'Actor', 'Rating'])

Moviedf
# Out:
#                          Title                             Genre  ...                                      Actor Rating
# 0                           조커                      액션, 드라마, 스릴러  ...                   호아킨 피닉스, 재지 비츠, 로버트 드 니로   9.25
# 1                    가장 보통의 연애                            멜로/로맨스  ...                                   김래원, 공효진   8.27
# 2                         퍼펙트맨                          코미디, 드라마  ...               설경구, 조진웅, 허준호, 진선규, 지승현, 김사랑   8.02
# 3                장사리 : 잊혀진 영웅들                                전쟁  ...                    김명민, 최민호, 김성철, 김인권, 곽시양   8.39
# 4             소피와 드래곤: 마법책의 비밀                    애니메이션, 판타지, 모험  ...                                   정유정, 김명준   6.00
# 5                 나쁜 녀석들: 더 무비                            범죄, 액션  ...                         마동석, 김상중, 김아중, 장기용   6.58
# 6                        양자물리학                                범죄  ...          박해수, 서예지, 김상호, 김응수, 변희봉, 김영재, 이창훈   8.50
# 7         원스 어폰 어 타임... 인 할리우드                          드라마, 코미디  ...                 레오나르도 디카프리오, 브래드 피트, 마고 로비   7.60
# 8                      몬스터 하우스                             애니메이션  ...                        베키 지, 조쉬 펙, 올리비아 홀트   0.00
# 9                           벌새                               드라마  ...                                   박지후, 김새벽   8.98
# 10                        레플리카                 범죄, 미스터리, SF, 스릴러  ...                  키아누 리브스, 앨리스 이브, 토머스 미들디치   6.85
# 11        극장판 헬로카봇 : 달나라를 구해줘!                             애니메이션  ...                         이지현, 김용준, 양정화, 조경이   7.51
# 12                     애드 아스트라                           SF, 스릴러  ...                                     브래드 피트   7.23
# 13                오션스: 문어구출대작전                             애니메이션  ...      남도형, 김소희, 강은애, 김경희, 민아, 김보나, 서반석, 이창민   0.00
# 14                          메기                    드라마, 미스터리, 코미디  ...                         이주영, 문소리, 구교환, 천우희   8.22
# 15                       미드 90                          코미디, 드라마  ...                                      서니 설직   8.57
# 16                       예스터데이                               드라마  ...                             히메쉬 파텔, 릴리 제임스   6.60
# 17  100일 동안 100가지로 100퍼센트 행복찾기                               코미디  ...                  플로리안 데이비드 핏츠, 마치아스 슈와바이어퍼   8.90
# 18                       아워 바디                               드라마  ...                              최희서, 안지혜, 김정영   7.14
# 19                        미드소마                     공포, 미스터리, 드라마  ...             플로렌스 퓨, 잭 레이너, 윌 폴터, 윌리엄 잭슨 하퍼   6.64
# 20                 타짜: 원 아이드 잭                           범죄, 드라마  ...                              박정민, 류승범, 최유화   5.47
# 21                         더 룸                         미스터리, 스릴러  ...                            올가 쿠릴렌코, 케빈 얀센스   7.99
# 22                         우리집                           드라마, 가족  ...                              김나연, 김시아, 주예림   8.80
# 23                   마왕의 딸 이리샤                             애니메이션  ...                                   천우희, 심희섭   7.71
# 24                      뷰티풀 보이                               드라마  ...                            스티브 카렐, 티모시 샬라메   8.17
# 25                 나의 노래는 멀리멀리                             다큐멘터리  ...                                   김지희, 이순도   0.00
# 26                      트루 시크릿                 드라마, 멜로/로맨스, 미스터리  ...                                    줄리엣 비노쉬   0.00
# 27                         주전장                             다큐멘터리  ...                                      디터 람스   9.54
# 28                       디터 람스                             다큐멘터리  ...                                   이다은, 박성영   9.31
# 29                       슈퍼 햄찌                           가족, 판타지  ...                         방연지, 김선혜, 조경이, 채민지   7.04
# ..                         ...                               ...  ...                                        ...    ...
# 70                       틴 스피릿                               드라마  ...                     최무룡, 신영균, 황해, 곽규석, 박노식   6.61
# 71                  폴란드로 간 아이들                        다큐멘터리, 드라마  ...                빌 스카스가드, 제임스 맥어보이, 제시카 차스테인   9.33
# 72                      5인의 해병                           전쟁, 드라마  ...           호아킨 피닉스, 에이미 아담스, 루니 마라, 스칼렛 요한슨   8.35
# 73                그것: 두 번째 이야기                               스릴러  ...                                   곽민규, 김시은   6.24
# 74                          그녀                       드라마, 멜로/로맨스  ...                      최종원, 박민상, 박상면, 조안, 춘자   8.50
# 75                    내가 사는 세상                               드라마  ...                   미셀 부케, 크리스타 테렛, 빈센트 로티어스   7.96
# 76                      늙은 자전거                           가족, 드라마  ...                     존 웨인, 모린 오하라, 베리 피츠제럴드   8.12
# 77                        르누아르                               드라마  ...                                        송호준   7.30
# 78                    말 없는 사나이                  코미디, 드라마, 멜로/로맨스  ...       밋첼 머소, 샘 러너, 스펜서 로크, 스티브 부세미, 매기 질렌할   8.00
# 79                    망원동 인공위성                             다큐멘터리  ...           릴리 레이브, 티모시 샬라메, 릴리 라인하트, 앤서니 퀸틀   8.24
# 80                     몬스터 하우스  애니메이션, 모험, 코미디, 공포, 판타지, 가족, 드라마  ...                    김연우, 전태열, 신용우, 배수빈, 김새해   7.37
# 81                     미스 스티븐스                               드라마  ...                            브리 라슨, 우카쉬 엠부드카   7.81
# 82                      발명왕 볼트                         애니메이션, 모험  ...                              문영동, 김소민, 김려원   4.95
# 83                       별의 정원                             애니메이션  ...                                        백서빈   9.54
# 84                   블루스 인 인디아                  코미디, 뮤지컬, 멜로/로맨스  ...  캐럴 베이커, 리J.콥, 헨리 폰다, 캐롤린 존스, 칼 말든, 그레고리 펙   6.50
# 85                      사랑의 선물                               드라마  ...                          스테파니 커밍, 크리스토프 배치   9.65
# 86                        산상수훈                               드라마  ...                             살만 칸, 아누쉬카 샤르마   6.52
# 87                      서부 개척사                       서부, 모험, 드라마  ...                         아유쉬만 커라나, 부미 페드네카르   8.42
# 88                 셜리에 관한 모든 것                               드라마  ...                                        박누가   6.60
# 89                          술탄                       코미디, 멜로/로맨스  ...                  혜광 스님, 이승호, 이현행, 이정수, 박기태   9.00
# 90                   아내 업고 달리기                   코미디, 멜로/로맨스, 가족  ...                      메나 마수드, 윌 스미스, 나오미 스콧   8.96
# 91                  아픈 만큼 사랑한다                             다큐멘터리  ...                           노아 자베드라, 발레리 파흐너   9.72
# 92                         악사들                        드라마, 다큐멘터리  ...                   로망 뒤리스, 올가 쿠릴렌코, 팡틴 아흐뒤엥   8.37
# 93                         알라딘          모험, 가족, 판타지, 뮤지컬, 멜로/로맨스  ...                      존 웨인, 스튜어트 휘트먼, 이나 밸린   9.39
# 94            에곤 쉴레: 욕망이 그린 그림                               드라마  ...                                      타샤 튜더   7.93
# 95                     인 더 더스트                                SF  ...                            라이언 고슬링, 클레어 포이   5.82
# 96                       코만체로스                            액션, 서부  ...                          김재욱, 진아름, 김지유, 정원   6.62
# 97                       타샤 튜더                             다큐멘터리  ...                     티모시 샬라메, 마이카 먼로, 알렉스 로   9.04
# 98                        퍼스트맨                           SF, 드라마  ...         알리스태어 브래머, 에바 노블자다, 홍광호, 존 존 브라이언스   6.96
# 99                      플랑크 상수                               드라마  ...                                   정우성, 고소영   5.78
#
# [100 rows x 5 columns]
